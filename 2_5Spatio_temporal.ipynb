# %%
cd '/content/drive/MyDrive/76_new'
# Out:
# /content/drive/MyDrive/76_new

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import datetime

import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
# from model import RaSCNN

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, initializers, regularizers
import tensorflow.keras.backend as K

# fix CUDNN_STATUS_INTERNAL_ERROR
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# Perform PCA
do_pca = False

# %%
def convert_to_one_hot(in_arr):
    in_arr = in_arr.reshape((in_arr.shape[0],))
    in_arr = in_arr.astype(int)
    in_arr_1h = np.zeros((in_arr.size, in_arr.max()+1))
    in_arr_1h[np.arange(in_arr.size),in_arr] = 1
    return in_arr_1h

# %%
X_train_valid = np.load("Dataset/X_train_valid.npy").astype(np.float32)
y_train_valid = np.load("Dataset/y_train_valid.npy").astype(np.float32)
person_train_valid = np.load("Dataset/person_train_valid.npy").astype(np.float32)
X_test = np.load("Dataset/X_test.npy").astype(np.float32)
y_test = np.load("Dataset/y_test.npy").astype(np.float32)
person_test = np.load("Dataset/person_test.npy").astype(np.float32)

y_train_valid -= 769
y_test -= 769
# print('y_train_valid:', y_train_valid[:10])
# print('y_test:', y_test[:10])
# X_train_valid, y_train_valid = data_prep(X_train_valid, y_train_valid, 2, 2, True)
# X_test, y_test = data_prep(X_test, y_test, 2, 2, True)

y_train_valid_1h = convert_to_one_hot(y_train_valid)
y_test_1h = convert_to_one_hot(y_test)

# %%
print(X_train_valid.shape)
print(y_train_valid_1h.shape)
# Out:
# (2115, 22, 1000)
# (2115, 4)

# %% [markdown]
# ## Normalization

# %%
X_train_valid -= np.expand_dims(np.mean(X_train_valid, axis=-1), -1)
X_test -= np.expand_dims(np.mean(X_test, axis=-1), -1)
X_train_valid /= np.expand_dims(np.std(X_train_valid, axis=-1), -1)
X_test /= np.expand_dims(np.std(X_test, axis=-1), -1)

X_train_valid = X_train_valid.transpose((0, 2, 1))

# %% [markdown]
# ##Model

# %%
def RaSCNN(inputshape, outputshape, params=None):
    """
    Spatial summary convolutional neural network augmented with attention
    focused recurrence (Ra-SCNN) by Kostas, Pang, and Rudzics in "Machine
    learning for MEG during speec tasks."
    Adapted from https://github.com/SPOClab-ca/SCNN/blob/master/SCNN/models.py
    """
    ret_seq = True
    att_depth = 4
    attention = 76
    temp_layers = 4
    steps = 2
    temporal = 24
    temp_pool = 20

    lunits = [200, 40]
    activation = keras.activations.selu
    reg = float(0.01)
    dropout = 0.55


    ins = keras.layers.Input(inputshape)
    conv = keras.layers.Reshape((inputshape[0], inputshape[1], 1))(ins)


    ###Spatial Conv
    spatial_filters = 128
    conv = keras.layers.Conv2D(spatial_filters, kernel_size=(1, 11), activation=activation, name='spatial_conv1', kernel_regularizer=tf.keras.regularizers.l2(reg))(conv)
    conv = keras.layers.Conv2D(spatial_filters, kernel_size=(1, 12), activation=activation, name='spatial_conv2', kernel_regularizer=tf.keras.regularizers.l2(reg))(conv)
    conv = keras.layers.BatchNormalization()(conv)
    conv = keras.layers.SpatialDropout2D(dropout)(conv)


    ###Temporal Conv
    temporal_filters = 64
    conv = keras.layers.Conv2D(temporal_filters, (temporal, 1), activation=activation,
            use_bias=False, name='temporal_conv1',
            kernel_regularizer=tf.keras.regularizers.l2(reg))(conv)
    conv = keras.layers.Conv2D(temporal_filters, (temporal, 1), activation=activation,
            use_bias=False, name='temporal_conv2',
            kernel_regularizer=tf.keras.regularizers.l2(reg))(conv)
    conv = keras.layers.Conv2D(temporal_filters, (temporal, 1), activation=activation,
            use_bias=False, name='temporal_conv3',
            kernel_regularizer=tf.keras.regularizers.l2(reg))(conv)
    conv = keras.layers.Conv2D(temporal_filters, (temporal, 1), activation=activation,
            use_bias=False, name='temporal_conv4',
            kernel_regularizer=tf.keras.regularizers.l2(reg))(conv)

    conv = keras.layers.BatchNormalization()(conv)
    conv = keras.layers.AveragePooling2D((temp_pool, 1,))(conv)
    conv = keras.layers.SpatialDropout2D(dropout)(conv)
    conv = keras.layers.Reshape((45, temporal_filters))(conv)

    lstm = tf.keras.layers.LSTM(units=attention, implementation=2,
                                dropout=dropout, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(reg))
    attn = keras.layers.Bidirectional(lstm)(conv)
    conv = keras.layers.BatchNormalization()(attn)

    # if ret_seq:
    conv = keras.layers.Flatten()(conv)
    outs = conv

    outs = keras.layers.Dense(outputshape, activation='softmax')(outs)

    return keras.models.Model(ins, outs)

# %%
model = RaSCNN(inputshape=(1000, 22), outputshape=4)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1000, 22)]        0
#
#  reshape (Reshape)           (None, 1000, 22, 1)       0
#
#  spatial_conv1 (Conv2D)      (None, 1000, 12, 128)     1536
#
#  spatial_conv2 (Conv2D)      (None, 1000, 1, 128)      196736
#
#  batch_normalization (BatchN  (None, 1000, 1, 128)     512
#  ormalization)
#
#  spatial_dropout2d (SpatialD  (None, 1000, 1, 128)     0
#  ropout2D)
#
#  temporal_conv1 (Conv2D)     (None, 977, 1, 64)        196608
#
#  temporal_conv2 (Conv2D)     (None, 954, 1, 64)        98304
#
#  temporal_conv3 (Conv2D)     (None, 931, 1, 64)        98304
#
#  temporal_conv4 (Conv2D)     (None, 908, 1, 64)        98304
#
#  batch_normalization_1 (Batc  (None, 908, 1, 64)       256
#  hNormalization)
#
#  average_pooling2d (AverageP  (None, 45, 1, 64)        0
#  ooling2D)
#
#  spatial_dropout2d_1 (Spatia  (None, 45, 1, 64)        0
#  lDropout2D)
#
#  reshape_1 (Reshape)         (None, 45, 64)            0
#
#  bidirectional (Bidirectiona  (None, 45, 152)          85728
#  l)
#
#  batch_normalization_2 (Batc  (None, 45, 152)          608
#  hNormalization)
#
#  flatten (Flatten)           (None, 6840)              0
#
#  dense (Dense)               (None, 4)                 27364
#
# =================================================================
# Total params: 804,260
# Trainable params: 803,572
# Non-trainable params: 688
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss=tf.keras.losses.CategoricalCrossentropy(),
                  metrics=[tf.keras.metrics.CategoricalAccuracy()])

callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        patience=10,
        factor=0.5,
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath= 'model_{epoch:03d}.ckpt',
        save_best_only=False,
        save_weights_only=True,
        verbose=1,
        monitor='val_categorical_accuracy',
        # monitor='val_loss'
    ),
]

# %%
loss_hist = model.fit(
        X_train_valid, y_train_valid_1h,
        validation_split=0.2,
        batch_size=64,
        epochs=250,
        verbose=2,
        callbacks=callbacks,

    )
# Out:
# Epoch 1/250
#
# Epoch 1: saving model to model_001.ckpt
# 27/27 - 26s - loss: 8.0785 - categorical_accuracy: 0.2630 - val_loss: 7.5249 - val_categorical_accuracy: 0.3239 - lr: 1.0000e-04 - 26s/epoch - 958ms/step
# Epoch 2/250
#
# Epoch 2: saving model to model_002.ckpt
# 27/27 - 7s - loss: 7.9225 - categorical_accuracy: 0.2908 - val_loss: 7.4519 - val_categorical_accuracy: 0.3499 - lr: 1.0000e-04 - 7s/epoch - 265ms/step
# Epoch 3/250
#
# Epoch 3: saving model to model_003.ckpt
# 27/27 - 7s - loss: 7.7641 - categorical_accuracy: 0.3156 - val_loss: 7.3797 - val_categorical_accuracy: 0.3499 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 4/250
#
# Epoch 4: saving model to model_004.ckpt
# 27/27 - 7s - loss: 7.6112 - categorical_accuracy: 0.3422 - val_loss: 7.3029 - val_categorical_accuracy: 0.3759 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 5/250
#
# Epoch 5: saving model to model_005.ckpt
# 27/27 - 7s - loss: 7.5103 - categorical_accuracy: 0.3853 - val_loss: 7.2341 - val_categorical_accuracy: 0.3972 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 6/250
#
# Epoch 6: saving model to model_006.ckpt
# 27/27 - 7s - loss: 7.4420 - categorical_accuracy: 0.3729 - val_loss: 7.1611 - val_categorical_accuracy: 0.3759 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 7/250
#
# Epoch 7: saving model to model_007.ckpt
# 27/27 - 7s - loss: 7.3538 - categorical_accuracy: 0.3700 - val_loss: 7.0691 - val_categorical_accuracy: 0.4303 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 8/250
#
# Epoch 8: saving model to model_008.ckpt
# 27/27 - 7s - loss: 7.2399 - categorical_accuracy: 0.4048 - val_loss: 6.9566 - val_categorical_accuracy: 0.4421 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 9/250
#
# Epoch 9: saving model to model_009.ckpt
# 27/27 - 7s - loss: 7.1424 - categorical_accuracy: 0.4125 - val_loss: 6.8786 - val_categorical_accuracy: 0.4775 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 10/250
#
# Epoch 10: saving model to model_010.ckpt
# 27/27 - 7s - loss: 7.0688 - categorical_accuracy: 0.4249 - val_loss: 6.7822 - val_categorical_accuracy: 0.4988 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 11/250
#
# Epoch 11: saving model to model_011.ckpt
# 27/27 - 7s - loss: 6.9712 - categorical_accuracy: 0.4444 - val_loss: 6.8061 - val_categorical_accuracy: 0.4870 - lr: 1.0000e-04 - 7s/epoch - 254ms/step
# Epoch 12/250
#
# Epoch 12: saving model to model_012.ckpt
# 27/27 - 7s - loss: 6.9058 - categorical_accuracy: 0.4397 - val_loss: 6.6982 - val_categorical_accuracy: 0.4988 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 13/250
#
# Epoch 13: saving model to model_013.ckpt
# 27/27 - 7s - loss: 6.7898 - categorical_accuracy: 0.4716 - val_loss: 6.6696 - val_categorical_accuracy: 0.4870 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 14/250
#
# Epoch 14: saving model to model_014.ckpt
# 27/27 - 7s - loss: 6.7217 - categorical_accuracy: 0.4563 - val_loss: 6.6583 - val_categorical_accuracy: 0.4941 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 15/250
#
# Epoch 15: saving model to model_015.ckpt
# 27/27 - 7s - loss: 6.6438 - categorical_accuracy: 0.4770 - val_loss: 6.6092 - val_categorical_accuracy: 0.4941 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 16/250
#
# Epoch 16: saving model to model_016.ckpt
# 27/27 - 7s - loss: 6.6044 - categorical_accuracy: 0.4645 - val_loss: 6.5089 - val_categorical_accuracy: 0.5177 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 17/250
#
# Epoch 17: saving model to model_017.ckpt
# 27/27 - 7s - loss: 6.4903 - categorical_accuracy: 0.4740 - val_loss: 6.4040 - val_categorical_accuracy: 0.5366 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 18/250
#
# Epoch 18: saving model to model_018.ckpt
# 27/27 - 7s - loss: 6.3760 - categorical_accuracy: 0.4947 - val_loss: 6.3339 - val_categorical_accuracy: 0.5674 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 19/250
#
# Epoch 19: saving model to model_019.ckpt
# 27/27 - 7s - loss: 6.3420 - categorical_accuracy: 0.4905 - val_loss: 6.2576 - val_categorical_accuracy: 0.5390 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 20/250
#
# Epoch 20: saving model to model_020.ckpt
# 27/27 - 7s - loss: 6.2208 - categorical_accuracy: 0.5266 - val_loss: 6.2441 - val_categorical_accuracy: 0.5343 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 21/250
#
# Epoch 21: saving model to model_021.ckpt
# 27/27 - 7s - loss: 6.1616 - categorical_accuracy: 0.5296 - val_loss: 6.2168 - val_categorical_accuracy: 0.5201 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 22/250
#
# Epoch 22: saving model to model_022.ckpt
# 27/27 - 7s - loss: 6.1022 - categorical_accuracy: 0.5284 - val_loss: 6.0758 - val_categorical_accuracy: 0.5485 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 23/250
#
# Epoch 23: saving model to model_023.ckpt
# 27/27 - 7s - loss: 6.0480 - categorical_accuracy: 0.5183 - val_loss: 5.9470 - val_categorical_accuracy: 0.5816 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 24/250
#
# Epoch 24: saving model to model_024.ckpt
# 27/27 - 7s - loss: 5.9503 - categorical_accuracy: 0.5473 - val_loss: 6.0074 - val_categorical_accuracy: 0.5437 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 25/250
#
# Epoch 25: saving model to model_025.ckpt
# 27/27 - 7s - loss: 5.8711 - categorical_accuracy: 0.5473 - val_loss: 5.8527 - val_categorical_accuracy: 0.5603 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 26/250
#
# Epoch 26: saving model to model_026.ckpt
# 27/27 - 7s - loss: 5.7874 - categorical_accuracy: 0.5455 - val_loss: 5.7597 - val_categorical_accuracy: 0.5816 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 27/250
#
# Epoch 27: saving model to model_027.ckpt
# 27/27 - 7s - loss: 5.7268 - categorical_accuracy: 0.5697 - val_loss: 5.7543 - val_categorical_accuracy: 0.5792 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 28/250
#
# Epoch 28: saving model to model_028.ckpt
# 27/27 - 7s - loss: 5.6488 - categorical_accuracy: 0.5680 - val_loss: 5.6429 - val_categorical_accuracy: 0.5863 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 29/250
#
# Epoch 29: saving model to model_029.ckpt
# 27/27 - 7s - loss: 5.5725 - categorical_accuracy: 0.5816 - val_loss: 5.5198 - val_categorical_accuracy: 0.6052 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 30/250
#
# Epoch 30: saving model to model_030.ckpt
# 27/27 - 7s - loss: 5.5600 - categorical_accuracy: 0.5597 - val_loss: 5.4728 - val_categorical_accuracy: 0.6147 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 31/250
#
# Epoch 31: saving model to model_031.ckpt
# 27/27 - 7s - loss: 5.4585 - categorical_accuracy: 0.5910 - val_loss: 5.3710 - val_categorical_accuracy: 0.6194 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 32/250
#
# Epoch 32: saving model to model_032.ckpt
# 27/27 - 7s - loss: 5.3533 - categorical_accuracy: 0.5934 - val_loss: 5.3690 - val_categorical_accuracy: 0.6052 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 33/250
#
# Epoch 33: saving model to model_033.ckpt
# 27/27 - 7s - loss: 5.3140 - categorical_accuracy: 0.5940 - val_loss: 5.2986 - val_categorical_accuracy: 0.6170 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 34/250
#
# Epoch 34: saving model to model_034.ckpt
# 27/27 - 7s - loss: 5.2376 - categorical_accuracy: 0.6052 - val_loss: 5.2367 - val_categorical_accuracy: 0.6288 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 35/250
#
# Epoch 35: saving model to model_035.ckpt
# 27/27 - 7s - loss: 5.1739 - categorical_accuracy: 0.6206 - val_loss: 5.2636 - val_categorical_accuracy: 0.5934 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 36/250
#
# Epoch 36: saving model to model_036.ckpt
# 27/27 - 7s - loss: 5.0790 - categorical_accuracy: 0.6300 - val_loss: 5.1283 - val_categorical_accuracy: 0.6454 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 37/250
#
# Epoch 37: saving model to model_037.ckpt
# 27/27 - 7s - loss: 5.0108 - categorical_accuracy: 0.6306 - val_loss: 5.0414 - val_categorical_accuracy: 0.6336 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 38/250
#
# Epoch 38: saving model to model_038.ckpt
# 27/27 - 7s - loss: 4.9332 - categorical_accuracy: 0.6466 - val_loss: 4.9947 - val_categorical_accuracy: 0.6430 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 39/250
#
# Epoch 39: saving model to model_039.ckpt
# 27/27 - 7s - loss: 4.9031 - categorical_accuracy: 0.6413 - val_loss: 4.9615 - val_categorical_accuracy: 0.6288 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 40/250
#
# Epoch 40: saving model to model_040.ckpt
# 27/27 - 7s - loss: 4.8707 - categorical_accuracy: 0.6342 - val_loss: 4.9065 - val_categorical_accuracy: 0.6501 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 41/250
#
# Epoch 41: saving model to model_041.ckpt
# 27/27 - 7s - loss: 4.7666 - categorical_accuracy: 0.6619 - val_loss: 4.8021 - val_categorical_accuracy: 0.6619 - lr: 1.0000e-04 - 7s/epoch - 255ms/step
# Epoch 42/250
#
# Epoch 42: saving model to model_042.ckpt
# 27/27 - 7s - loss: 4.7001 - categorical_accuracy: 0.6631 - val_loss: 4.7685 - val_categorical_accuracy: 0.6478 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 43/250
#
# Epoch 43: saving model to model_043.ckpt
# 27/27 - 7s - loss: 4.6343 - categorical_accuracy: 0.6720 - val_loss: 4.6656 - val_categorical_accuracy: 0.6856 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 44/250
#
# Epoch 44: saving model to model_044.ckpt
# 27/27 - 7s - loss: 4.5890 - categorical_accuracy: 0.6673 - val_loss: 4.6086 - val_categorical_accuracy: 0.6761 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 45/250
#
# Epoch 45: saving model to model_045.ckpt
# 27/27 - 7s - loss: 4.5210 - categorical_accuracy: 0.6826 - val_loss: 4.5755 - val_categorical_accuracy: 0.6714 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 46/250
#
# Epoch 46: saving model to model_046.ckpt
# 27/27 - 7s - loss: 4.4787 - categorical_accuracy: 0.6749 - val_loss: 4.5068 - val_categorical_accuracy: 0.6809 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 47/250
#
# Epoch 47: saving model to model_047.ckpt
# 27/27 - 7s - loss: 4.4120 - categorical_accuracy: 0.6820 - val_loss: 4.5027 - val_categorical_accuracy: 0.6643 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 48/250
#
# Epoch 48: saving model to model_048.ckpt
# 27/27 - 7s - loss: 4.3655 - categorical_accuracy: 0.6779 - val_loss: 4.4539 - val_categorical_accuracy: 0.6572 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 49/250
#
# Epoch 49: saving model to model_049.ckpt
# 27/27 - 7s - loss: 4.2934 - categorical_accuracy: 0.6909 - val_loss: 4.3991 - val_categorical_accuracy: 0.6785 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 50/250
#
# Epoch 50: saving model to model_050.ckpt
# 27/27 - 7s - loss: 4.2605 - categorical_accuracy: 0.6974 - val_loss: 4.3468 - val_categorical_accuracy: 0.6856 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 51/250
#
# Epoch 51: saving model to model_051.ckpt
# 27/27 - 7s - loss: 4.1975 - categorical_accuracy: 0.7009 - val_loss: 4.3304 - val_categorical_accuracy: 0.6809 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 52/250
#
# Epoch 52: saving model to model_052.ckpt
# 27/27 - 7s - loss: 4.1366 - categorical_accuracy: 0.7128 - val_loss: 4.1995 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 53/250
#
# Epoch 53: saving model to model_053.ckpt
# 27/27 - 7s - loss: 4.0793 - categorical_accuracy: 0.7092 - val_loss: 4.2055 - val_categorical_accuracy: 0.6903 - lr: 1.0000e-04 - 7s/epoch - 256ms/step
# Epoch 54/250
#
# Epoch 54: saving model to model_054.ckpt
# 27/27 - 7s - loss: 4.0159 - categorical_accuracy: 0.7305 - val_loss: 4.1910 - val_categorical_accuracy: 0.6856 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 55/250
#
# Epoch 55: saving model to model_055.ckpt
# 27/27 - 7s - loss: 3.9757 - categorical_accuracy: 0.7157 - val_loss: 4.1118 - val_categorical_accuracy: 0.6879 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 56/250
#
# Epoch 56: saving model to model_056.ckpt
# 27/27 - 7s - loss: 3.9406 - categorical_accuracy: 0.7199 - val_loss: 4.0641 - val_categorical_accuracy: 0.6998 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 57/250
#
# Epoch 57: saving model to model_057.ckpt
# 27/27 - 7s - loss: 3.8937 - categorical_accuracy: 0.7175 - val_loss: 4.0436 - val_categorical_accuracy: 0.6879 - lr: 1.0000e-04 - 7s/epoch - 258ms/step
# Epoch 58/250
#
# Epoch 58: saving model to model_058.ckpt
# 27/27 - 7s - loss: 3.8582 - categorical_accuracy: 0.7104 - val_loss: 3.9760 - val_categorical_accuracy: 0.6927 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 59/250
#
# Epoch 59: saving model to model_059.ckpt
# 27/27 - 7s - loss: 3.7757 - categorical_accuracy: 0.7317 - val_loss: 3.9136 - val_categorical_accuracy: 0.7045 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 60/250
#
# Epoch 60: saving model to model_060.ckpt
# 27/27 - 7s - loss: 3.7490 - categorical_accuracy: 0.7317 - val_loss: 3.9319 - val_categorical_accuracy: 0.6879 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 61/250
#
# Epoch 61: saving model to model_061.ckpt
# 27/27 - 7s - loss: 3.6874 - categorical_accuracy: 0.7287 - val_loss: 3.8524 - val_categorical_accuracy: 0.7092 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 62/250
#
# Epoch 62: saving model to model_062.ckpt
# 27/27 - 7s - loss: 3.6554 - categorical_accuracy: 0.7346 - val_loss: 3.7546 - val_categorical_accuracy: 0.7281 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 63/250
#
# Epoch 63: saving model to model_063.ckpt
# 27/27 - 7s - loss: 3.5908 - categorical_accuracy: 0.7417 - val_loss: 3.7996 - val_categorical_accuracy: 0.6856 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 64/250
#
# Epoch 64: saving model to model_064.ckpt
# 27/27 - 7s - loss: 3.5159 - categorical_accuracy: 0.7565 - val_loss: 3.7628 - val_categorical_accuracy: 0.6761 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 65/250
#
# Epoch 65: saving model to model_065.ckpt
# 27/27 - 7s - loss: 3.4776 - categorical_accuracy: 0.7654 - val_loss: 3.7659 - val_categorical_accuracy: 0.6690 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 66/250
#
# Epoch 66: saving model to model_066.ckpt
# 27/27 - 7s - loss: 3.4327 - categorical_accuracy: 0.7654 - val_loss: 3.6466 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 67/250
#
# Epoch 67: saving model to model_067.ckpt
# 27/27 - 7s - loss: 3.4269 - categorical_accuracy: 0.7494 - val_loss: 3.6083 - val_categorical_accuracy: 0.7092 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 68/250
#
# Epoch 68: saving model to model_068.ckpt
# 27/27 - 7s - loss: 3.3657 - categorical_accuracy: 0.7535 - val_loss: 3.5707 - val_categorical_accuracy: 0.7045 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 69/250
#
# Epoch 69: saving model to model_069.ckpt
# 27/27 - 7s - loss: 3.3190 - categorical_accuracy: 0.7642 - val_loss: 3.5431 - val_categorical_accuracy: 0.6998 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 70/250
#
# Epoch 70: saving model to model_070.ckpt
# 27/27 - 7s - loss: 3.2924 - categorical_accuracy: 0.7547 - val_loss: 3.5118 - val_categorical_accuracy: 0.6856 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 71/250
#
# Epoch 71: saving model to model_071.ckpt
# 27/27 - 7s - loss: 3.2139 - categorical_accuracy: 0.7571 - val_loss: 3.3979 - val_categorical_accuracy: 0.7281 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 72/250
#
# Epoch 72: saving model to model_072.ckpt
# 27/27 - 7s - loss: 3.1809 - categorical_accuracy: 0.7725 - val_loss: 3.3889 - val_categorical_accuracy: 0.7305 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 73/250
#
# Epoch 73: saving model to model_073.ckpt
# 27/27 - 7s - loss: 3.1461 - categorical_accuracy: 0.7636 - val_loss: 3.3982 - val_categorical_accuracy: 0.6974 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 74/250
#
# Epoch 74: saving model to model_074.ckpt
# 27/27 - 7s - loss: 3.1140 - categorical_accuracy: 0.7730 - val_loss: 3.3593 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 75/250
#
# Epoch 75: saving model to model_075.ckpt
# 27/27 - 7s - loss: 3.0790 - categorical_accuracy: 0.7796 - val_loss: 3.2821 - val_categorical_accuracy: 0.7234 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 76/250
#
# Epoch 76: saving model to model_076.ckpt
# 27/27 - 7s - loss: 3.0494 - categorical_accuracy: 0.7689 - val_loss: 3.2823 - val_categorical_accuracy: 0.7021 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 77/250
#
# Epoch 77: saving model to model_077.ckpt
# 27/27 - 7s - loss: 3.0308 - categorical_accuracy: 0.7642 - val_loss: 3.3779 - val_categorical_accuracy: 0.6738 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 78/250
#
# Epoch 78: saving model to model_078.ckpt
# 27/27 - 7s - loss: 2.9415 - categorical_accuracy: 0.7914 - val_loss: 3.2491 - val_categorical_accuracy: 0.7045 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 79/250
#
# Epoch 79: saving model to model_079.ckpt
# 27/27 - 7s - loss: 2.9016 - categorical_accuracy: 0.7979 - val_loss: 3.1871 - val_categorical_accuracy: 0.7021 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 80/250
#
# Epoch 80: saving model to model_080.ckpt
# 27/27 - 7s - loss: 2.8769 - categorical_accuracy: 0.7920 - val_loss: 3.1665 - val_categorical_accuracy: 0.7187 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 81/250
#
# Epoch 81: saving model to model_081.ckpt
# 27/27 - 7s - loss: 2.8440 - categorical_accuracy: 0.7926 - val_loss: 3.1579 - val_categorical_accuracy: 0.7092 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 82/250
#
# Epoch 82: saving model to model_082.ckpt
# 27/27 - 7s - loss: 2.7978 - categorical_accuracy: 0.8020 - val_loss: 3.0237 - val_categorical_accuracy: 0.7329 - lr: 1.0000e-04 - 7s/epoch - 253ms/step
# Epoch 83/250
#
# Epoch 83: saving model to model_083.ckpt
# 27/27 - 7s - loss: 2.7386 - categorical_accuracy: 0.8209 - val_loss: 3.0842 - val_categorical_accuracy: 0.7258 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 84/250
#
# Epoch 84: saving model to model_084.ckpt
# 27/27 - 7s - loss: 2.7655 - categorical_accuracy: 0.7908 - val_loss: 3.1313 - val_categorical_accuracy: 0.6927 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 85/250
#
# Epoch 85: saving model to model_085.ckpt
# 27/27 - 7s - loss: 2.6978 - categorical_accuracy: 0.8038 - val_loss: 2.9138 - val_categorical_accuracy: 0.7541 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 86/250
#
# Epoch 86: saving model to model_086.ckpt
# 27/27 - 7s - loss: 2.6562 - categorical_accuracy: 0.8126 - val_loss: 2.9284 - val_categorical_accuracy: 0.7281 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 87/250
#
# Epoch 87: saving model to model_087.ckpt
# 27/27 - 7s - loss: 2.6175 - categorical_accuracy: 0.8103 - val_loss: 2.8778 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 88/250
#
# Epoch 88: saving model to model_088.ckpt
# 27/27 - 7s - loss: 2.6025 - categorical_accuracy: 0.8150 - val_loss: 2.9237 - val_categorical_accuracy: 0.7139 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 89/250
#
# Epoch 89: saving model to model_089.ckpt
# 27/27 - 7s - loss: 2.5396 - categorical_accuracy: 0.8304 - val_loss: 2.9431 - val_categorical_accuracy: 0.6998 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 90/250
#
# Epoch 90: saving model to model_090.ckpt
# 27/27 - 7s - loss: 2.5333 - categorical_accuracy: 0.8115 - val_loss: 2.7818 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 91/250
#
# Epoch 91: saving model to model_091.ckpt
# 27/27 - 7s - loss: 2.5079 - categorical_accuracy: 0.8186 - val_loss: 2.9317 - val_categorical_accuracy: 0.7210 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 92/250
#
# Epoch 92: saving model to model_092.ckpt
# 27/27 - 7s - loss: 2.4524 - categorical_accuracy: 0.8221 - val_loss: 3.0228 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 93/250
#
# Epoch 93: saving model to model_093.ckpt
# 27/27 - 7s - loss: 2.4318 - categorical_accuracy: 0.8387 - val_loss: 2.7433 - val_categorical_accuracy: 0.7541 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 94/250
#
# Epoch 94: saving model to model_094.ckpt
# 27/27 - 7s - loss: 2.4146 - categorical_accuracy: 0.8239 - val_loss: 2.7059 - val_categorical_accuracy: 0.7660 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 95/250
#
# Epoch 95: saving model to model_095.ckpt
# 27/27 - 7s - loss: 2.3633 - categorical_accuracy: 0.8274 - val_loss: 2.7455 - val_categorical_accuracy: 0.7258 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 96/250
#
# Epoch 96: saving model to model_096.ckpt
# 27/27 - 7s - loss: 2.3341 - categorical_accuracy: 0.8375 - val_loss: 2.7207 - val_categorical_accuracy: 0.7329 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 97/250
#
# Epoch 97: saving model to model_097.ckpt
# 27/27 - 7s - loss: 2.3437 - categorical_accuracy: 0.8245 - val_loss: 2.6983 - val_categorical_accuracy: 0.7470 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 98/250
#
# Epoch 98: saving model to model_098.ckpt
# 27/27 - 7s - loss: 2.2981 - categorical_accuracy: 0.8239 - val_loss: 2.7218 - val_categorical_accuracy: 0.7092 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 99/250
#
# Epoch 99: saving model to model_099.ckpt
# 27/27 - 7s - loss: 2.2557 - categorical_accuracy: 0.8410 - val_loss: 2.6085 - val_categorical_accuracy: 0.7423 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 100/250
#
# Epoch 100: saving model to model_100.ckpt
# 27/27 - 7s - loss: 2.2266 - categorical_accuracy: 0.8375 - val_loss: 2.5713 - val_categorical_accuracy: 0.7447 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 101/250
#
# Epoch 101: saving model to model_101.ckpt
# 27/27 - 7s - loss: 2.1921 - categorical_accuracy: 0.8392 - val_loss: 2.6049 - val_categorical_accuracy: 0.7187 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 102/250
#
# Epoch 102: saving model to model_102.ckpt
# 27/27 - 7s - loss: 2.1576 - categorical_accuracy: 0.8570 - val_loss: 2.5058 - val_categorical_accuracy: 0.7470 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 103/250
#
# Epoch 103: saving model to model_103.ckpt
# 27/27 - 7s - loss: 2.1516 - categorical_accuracy: 0.8457 - val_loss: 2.5044 - val_categorical_accuracy: 0.7707 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 104/250
#
# Epoch 104: saving model to model_104.ckpt
# 27/27 - 7s - loss: 2.1117 - categorical_accuracy: 0.8576 - val_loss: 2.5128 - val_categorical_accuracy: 0.7329 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 105/250
#
# Epoch 105: saving model to model_105.ckpt
# 27/27 - 7s - loss: 2.0796 - categorical_accuracy: 0.8517 - val_loss: 2.5193 - val_categorical_accuracy: 0.7258 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 106/250
#
# Epoch 106: saving model to model_106.ckpt
# 27/27 - 7s - loss: 2.0685 - categorical_accuracy: 0.8487 - val_loss: 2.6224 - val_categorical_accuracy: 0.7069 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 107/250
#
# Epoch 107: saving model to model_107.ckpt
# 27/27 - 7s - loss: 2.0306 - categorical_accuracy: 0.8546 - val_loss: 2.3980 - val_categorical_accuracy: 0.7589 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 108/250
#
# Epoch 108: saving model to model_108.ckpt
# 27/27 - 7s - loss: 1.9932 - categorical_accuracy: 0.8670 - val_loss: 2.4546 - val_categorical_accuracy: 0.7376 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 109/250
#
# Epoch 109: saving model to model_109.ckpt
# 27/27 - 7s - loss: 1.9934 - categorical_accuracy: 0.8605 - val_loss: 2.4228 - val_categorical_accuracy: 0.7352 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 110/250
#
# Epoch 110: saving model to model_110.ckpt
# 27/27 - 7s - loss: 1.9749 - categorical_accuracy: 0.8611 - val_loss: 2.3745 - val_categorical_accuracy: 0.7423 - lr: 1.0000e-04 - 7s/epoch - 258ms/step
# Epoch 111/250
#
# Epoch 111: saving model to model_111.ckpt
# 27/27 - 7s - loss: 1.9613 - categorical_accuracy: 0.8534 - val_loss: 2.4267 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 112/250
#
# Epoch 112: saving model to model_112.ckpt
# 27/27 - 7s - loss: 1.9288 - categorical_accuracy: 0.8652 - val_loss: 2.3999 - val_categorical_accuracy: 0.7329 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 113/250
#
# Epoch 113: saving model to model_113.ckpt
# 27/27 - 7s - loss: 1.9118 - categorical_accuracy: 0.8670 - val_loss: 2.3949 - val_categorical_accuracy: 0.7187 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 114/250
#
# Epoch 114: saving model to model_114.ckpt
# 27/27 - 7s - loss: 1.8596 - categorical_accuracy: 0.8741 - val_loss: 2.3915 - val_categorical_accuracy: 0.7210 - lr: 1.0000e-04 - 7s/epoch - 260ms/step
# Epoch 115/250
#
# Epoch 115: saving model to model_115.ckpt
# 27/27 - 7s - loss: 1.8467 - categorical_accuracy: 0.8783 - val_loss: 2.3954 - val_categorical_accuracy: 0.7092 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 116/250
#
# Epoch 116: saving model to model_116.ckpt
# 27/27 - 7s - loss: 1.8181 - categorical_accuracy: 0.8877 - val_loss: 2.3402 - val_categorical_accuracy: 0.7234 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 117/250
#
# Epoch 117: saving model to model_117.ckpt
# 27/27 - 7s - loss: 1.8065 - categorical_accuracy: 0.8747 - val_loss: 2.3378 - val_categorical_accuracy: 0.7258 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 118/250
#
# Epoch 118: saving model to model_118.ckpt
# 27/27 - 7s - loss: 1.8100 - categorical_accuracy: 0.8735 - val_loss: 2.3618 - val_categorical_accuracy: 0.7045 - lr: 1.0000e-04 - 7s/epoch - 254ms/step
# Epoch 119/250
#
# Epoch 119: saving model to model_119.ckpt
# 27/27 - 7s - loss: 1.7892 - categorical_accuracy: 0.8741 - val_loss: 2.2351 - val_categorical_accuracy: 0.7447 - lr: 1.0000e-04 - 7s/epoch - 256ms/step
# Epoch 120/250
#
# Epoch 120: saving model to model_120.ckpt
# 27/27 - 7s - loss: 1.7347 - categorical_accuracy: 0.8800 - val_loss: 2.2577 - val_categorical_accuracy: 0.7305 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 121/250
#
# Epoch 121: saving model to model_121.ckpt
# 27/27 - 7s - loss: 1.7393 - categorical_accuracy: 0.8788 - val_loss: 2.2365 - val_categorical_accuracy: 0.7494 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 122/250
#
# Epoch 122: saving model to model_122.ckpt
# 27/27 - 7s - loss: 1.7022 - categorical_accuracy: 0.8895 - val_loss: 2.2527 - val_categorical_accuracy: 0.7447 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 123/250
#
# Epoch 123: saving model to model_123.ckpt
# 27/27 - 7s - loss: 1.6782 - categorical_accuracy: 0.8907 - val_loss: 2.3087 - val_categorical_accuracy: 0.7234 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 124/250
#
# Epoch 124: saving model to model_124.ckpt
# 27/27 - 7s - loss: 1.6826 - categorical_accuracy: 0.8771 - val_loss: 2.4378 - val_categorical_accuracy: 0.6998 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 125/250
#
# Epoch 125: saving model to model_125.ckpt
# 27/27 - 7s - loss: 1.6477 - categorical_accuracy: 0.8848 - val_loss: 2.2373 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 126/250
#
# Epoch 126: saving model to model_126.ckpt
# 27/27 - 7s - loss: 1.6346 - categorical_accuracy: 0.8865 - val_loss: 2.1865 - val_categorical_accuracy: 0.7376 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 127/250
#
# Epoch 127: saving model to model_127.ckpt
# 27/27 - 7s - loss: 1.6219 - categorical_accuracy: 0.8842 - val_loss: 2.1572 - val_categorical_accuracy: 0.7494 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 128/250
#
# Epoch 128: saving model to model_128.ckpt
# 27/27 - 7s - loss: 1.5986 - categorical_accuracy: 0.8930 - val_loss: 2.1162 - val_categorical_accuracy: 0.7612 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 129/250
#
# Epoch 129: saving model to model_129.ckpt
# 27/27 - 7s - loss: 1.5745 - categorical_accuracy: 0.8995 - val_loss: 2.2690 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 130/250
#
# Epoch 130: saving model to model_130.ckpt
# 27/27 - 7s - loss: 1.5483 - categorical_accuracy: 0.9043 - val_loss: 2.1125 - val_categorical_accuracy: 0.7352 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 131/250
#
# Epoch 131: saving model to model_131.ckpt
# 27/27 - 7s - loss: 1.5470 - categorical_accuracy: 0.8954 - val_loss: 2.1009 - val_categorical_accuracy: 0.7589 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 132/250
#
# Epoch 132: saving model to model_132.ckpt
# 27/27 - 7s - loss: 1.5212 - categorical_accuracy: 0.9019 - val_loss: 2.1061 - val_categorical_accuracy: 0.7281 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 133/250
#
# Epoch 133: saving model to model_133.ckpt
# 27/27 - 7s - loss: 1.5131 - categorical_accuracy: 0.8907 - val_loss: 2.1670 - val_categorical_accuracy: 0.7258 - lr: 1.0000e-04 - 7s/epoch - 257ms/step
# Epoch 134/250
#
# Epoch 134: saving model to model_134.ckpt
# 27/27 - 7s - loss: 1.5184 - categorical_accuracy: 0.8895 - val_loss: 2.2825 - val_categorical_accuracy: 0.6974 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 135/250
#
# Epoch 135: saving model to model_135.ckpt
# 27/27 - 7s - loss: 1.4694 - categorical_accuracy: 0.9084 - val_loss: 2.0486 - val_categorical_accuracy: 0.7565 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 136/250
#
# Epoch 136: saving model to model_136.ckpt
# 27/27 - 7s - loss: 1.4274 - categorical_accuracy: 0.9167 - val_loss: 2.1082 - val_categorical_accuracy: 0.7139 - lr: 1.0000e-04 - 7s/epoch - 252ms/step
# Epoch 137/250
#
# Epoch 137: saving model to model_137.ckpt
# 27/27 - 7s - loss: 1.3995 - categorical_accuracy: 0.9214 - val_loss: 2.0352 - val_categorical_accuracy: 0.7494 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 138/250
#
# Epoch 138: saving model to model_138.ckpt
# 27/27 - 7s - loss: 1.4059 - categorical_accuracy: 0.9137 - val_loss: 2.1188 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 139/250
#
# Epoch 139: saving model to model_139.ckpt
# 27/27 - 7s - loss: 1.4329 - categorical_accuracy: 0.8936 - val_loss: 2.0308 - val_categorical_accuracy: 0.7470 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 140/250
#
# Epoch 140: saving model to model_140.ckpt
# 27/27 - 7s - loss: 1.4087 - categorical_accuracy: 0.9090 - val_loss: 2.1021 - val_categorical_accuracy: 0.7187 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 141/250
#
# Epoch 141: saving model to model_141.ckpt
# 27/27 - 7s - loss: 1.3726 - categorical_accuracy: 0.9096 - val_loss: 2.0466 - val_categorical_accuracy: 0.7329 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 142/250
#
# Epoch 142: saving model to model_142.ckpt
# 27/27 - 7s - loss: 1.3861 - categorical_accuracy: 0.9019 - val_loss: 1.9620 - val_categorical_accuracy: 0.7565 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 143/250
#
# Epoch 143: saving model to model_143.ckpt
# 27/27 - 7s - loss: 1.3729 - categorical_accuracy: 0.9019 - val_loss: 2.0131 - val_categorical_accuracy: 0.7305 - lr: 1.0000e-04 - 7s/epoch - 248ms/step
# Epoch 144/250
#
# Epoch 144: saving model to model_144.ckpt
# 27/27 - 7s - loss: 1.3306 - categorical_accuracy: 0.9108 - val_loss: 2.0363 - val_categorical_accuracy: 0.7234 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 145/250
#
# Epoch 145: saving model to model_145.ckpt
# 27/27 - 7s - loss: 1.3103 - categorical_accuracy: 0.9238 - val_loss: 1.8875 - val_categorical_accuracy: 0.7494 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 146/250
#
# Epoch 146: saving model to model_146.ckpt
# 27/27 - 7s - loss: 1.3427 - categorical_accuracy: 0.8995 - val_loss: 1.8995 - val_categorical_accuracy: 0.7518 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 147/250
#
# Epoch 147: saving model to model_147.ckpt
# 27/27 - 7s - loss: 1.3304 - categorical_accuracy: 0.9072 - val_loss: 2.1234 - val_categorical_accuracy: 0.7163 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 148/250
#
# Epoch 148: saving model to model_148.ckpt
# 27/27 - 7s - loss: 1.3106 - categorical_accuracy: 0.9037 - val_loss: 1.8745 - val_categorical_accuracy: 0.7470 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 149/250
#
# Epoch 149: saving model to model_149.ckpt
# 27/27 - 7s - loss: 1.2611 - categorical_accuracy: 0.9196 - val_loss: 1.9297 - val_categorical_accuracy: 0.7541 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 150/250
#
# Epoch 150: saving model to model_150.ckpt
# 27/27 - 7s - loss: 1.2566 - categorical_accuracy: 0.9173 - val_loss: 1.8293 - val_categorical_accuracy: 0.7636 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 151/250
#
# Epoch 151: saving model to model_151.ckpt
# 27/27 - 7s - loss: 1.2479 - categorical_accuracy: 0.9226 - val_loss: 1.9158 - val_categorical_accuracy: 0.7518 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 152/250
#
# Epoch 152: saving model to model_152.ckpt
# 27/27 - 7s - loss: 1.2600 - categorical_accuracy: 0.9060 - val_loss: 2.0855 - val_categorical_accuracy: 0.7210 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 153/250
#
# Epoch 153: saving model to model_153.ckpt
# 27/27 - 7s - loss: 1.2118 - categorical_accuracy: 0.9208 - val_loss: 1.9258 - val_categorical_accuracy: 0.7305 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 154/250
#
# Epoch 154: saving model to model_154.ckpt
# 27/27 - 7s - loss: 1.2503 - categorical_accuracy: 0.9102 - val_loss: 1.8641 - val_categorical_accuracy: 0.7329 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 155/250
#
# Epoch 155: saving model to model_155.ckpt
# 27/27 - 7s - loss: 1.2062 - categorical_accuracy: 0.9255 - val_loss: 1.8764 - val_categorical_accuracy: 0.7352 - lr: 1.0000e-04 - 7s/epoch - 255ms/step
# Epoch 156/250
#
# Epoch 156: saving model to model_156.ckpt
# 27/27 - 7s - loss: 1.1733 - categorical_accuracy: 0.9279 - val_loss: 1.9277 - val_categorical_accuracy: 0.7187 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 157/250
#
# Epoch 157: saving model to model_157.ckpt
# 27/27 - 7s - loss: 1.1937 - categorical_accuracy: 0.9155 - val_loss: 1.8875 - val_categorical_accuracy: 0.7352 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 158/250
#
# Epoch 158: saving model to model_158.ckpt
# 27/27 - 7s - loss: 1.1662 - categorical_accuracy: 0.9220 - val_loss: 2.1425 - val_categorical_accuracy: 0.6785 - lr: 1.0000e-04 - 7s/epoch - 249ms/step
# Epoch 159/250
#
# Epoch 159: saving model to model_159.ckpt
# 27/27 - 7s - loss: 1.1626 - categorical_accuracy: 0.9220 - val_loss: 2.0282 - val_categorical_accuracy: 0.7116 - lr: 1.0000e-04 - 7s/epoch - 251ms/step
# Epoch 160/250
#
# Epoch 160: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 160: saving model to model_160.ckpt
# 27/27 - 7s - loss: 1.1514 - categorical_accuracy: 0.9190 - val_loss: 2.0642 - val_categorical_accuracy: 0.6974 - lr: 1.0000e-04 - 7s/epoch - 250ms/step
# Epoch 161/250
#
# Epoch 161: saving model to model_161.ckpt
# 27/27 - 7s - loss: 1.1124 - categorical_accuracy: 0.9379 - val_loss: 1.8311 - val_categorical_accuracy: 0.7565 - lr: 5.0000e-05 - 7s/epoch - 249ms/step
# Epoch 162/250
#
# Epoch 162: saving model to model_162.ckpt
# 27/27 - 7s - loss: 1.0805 - categorical_accuracy: 0.9462 - val_loss: 1.8030 - val_categorical_accuracy: 0.7541 - lr: 5.0000e-05 - 7s/epoch - 251ms/step
# Epoch 163/250
#
# Epoch 163: saving model to model_163.ckpt
# 27/27 - 7s - loss: 1.0749 - categorical_accuracy: 0.9521 - val_loss: 2.0168 - val_categorical_accuracy: 0.7163 - lr: 5.0000e-05 - 7s/epoch - 251ms/step
# Epoch 164/250
#
# Epoch 164: saving model to model_164.ckpt
# 27/27 - 7s - loss: 1.0753 - categorical_accuracy: 0.9439 - val_loss: 1.7792 - val_categorical_accuracy: 0.7565 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 165/250
#
# Epoch 165: saving model to model_165.ckpt
# 27/27 - 7s - loss: 1.0448 - categorical_accuracy: 0.9533 - val_loss: 1.8577 - val_categorical_accuracy: 0.7494 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 166/250
#
# Epoch 166: saving model to model_166.ckpt
# 27/27 - 7s - loss: 1.0591 - categorical_accuracy: 0.9474 - val_loss: 1.7512 - val_categorical_accuracy: 0.7565 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 167/250
#
# Epoch 167: saving model to model_167.ckpt
# 27/27 - 7s - loss: 1.0311 - categorical_accuracy: 0.9545 - val_loss: 1.7258 - val_categorical_accuracy: 0.7778 - lr: 5.0000e-05 - 7s/epoch - 251ms/step
# Epoch 168/250
#
# Epoch 168: saving model to model_168.ckpt
# 27/27 - 7s - loss: 1.0276 - categorical_accuracy: 0.9580 - val_loss: 1.7898 - val_categorical_accuracy: 0.7660 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 169/250
#
# Epoch 169: saving model to model_169.ckpt
# 27/27 - 7s - loss: 1.0235 - categorical_accuracy: 0.9527 - val_loss: 1.7724 - val_categorical_accuracy: 0.7494 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 170/250
#
# Epoch 170: saving model to model_170.ckpt
# 27/27 - 7s - loss: 1.0378 - categorical_accuracy: 0.9480 - val_loss: 1.8602 - val_categorical_accuracy: 0.7447 - lr: 5.0000e-05 - 7s/epoch - 249ms/step
# Epoch 171/250
#
# Epoch 171: saving model to model_171.ckpt
# 27/27 - 7s - loss: 1.0212 - categorical_accuracy: 0.9551 - val_loss: 1.7301 - val_categorical_accuracy: 0.7541 - lr: 5.0000e-05 - 7s/epoch - 251ms/step
# Epoch 172/250
#
# Epoch 172: saving model to model_172.ckpt
# 27/27 - 7s - loss: 1.0002 - categorical_accuracy: 0.9574 - val_loss: 1.7767 - val_categorical_accuracy: 0.7589 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 173/250
#
# Epoch 173: saving model to model_173.ckpt
# 27/27 - 7s - loss: 0.9939 - categorical_accuracy: 0.9622 - val_loss: 1.8208 - val_categorical_accuracy: 0.7447 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 174/250
#
# Epoch 174: saving model to model_174.ckpt
# 27/27 - 7s - loss: 0.9941 - categorical_accuracy: 0.9580 - val_loss: 1.8133 - val_categorical_accuracy: 0.7352 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 175/250
#
# Epoch 175: saving model to model_175.ckpt
# 27/27 - 7s - loss: 0.9875 - categorical_accuracy: 0.9628 - val_loss: 1.8835 - val_categorical_accuracy: 0.7376 - lr: 5.0000e-05 - 7s/epoch - 249ms/step
# Epoch 176/250
#
# Epoch 176: saving model to model_176.ckpt
# 27/27 - 7s - loss: 0.9826 - categorical_accuracy: 0.9574 - val_loss: 1.7963 - val_categorical_accuracy: 0.7470 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 177/250
#
# Epoch 177: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 177: saving model to model_177.ckpt
# 27/27 - 7s - loss: 0.9946 - categorical_accuracy: 0.9480 - val_loss: 1.9203 - val_categorical_accuracy: 0.7092 - lr: 5.0000e-05 - 7s/epoch - 250ms/step
# Epoch 178/250
#
# Epoch 178: saving model to model_178.ckpt
# 27/27 - 7s - loss: 0.9676 - categorical_accuracy: 0.9645 - val_loss: 1.7640 - val_categorical_accuracy: 0.7565 - lr: 2.5000e-05 - 7s/epoch - 250ms/step
# Epoch 179/250
#
# Epoch 179: saving model to model_179.ckpt
# 27/27 - 7s - loss: 0.9648 - categorical_accuracy: 0.9586 - val_loss: 1.7752 - val_categorical_accuracy: 0.7494 - lr: 2.5000e-05 - 7s/epoch - 249ms/step
# Epoch 180/250
#
# Epoch 180: saving model to model_180.ckpt
# 27/27 - 7s - loss: 0.9582 - categorical_accuracy: 0.9651 - val_loss: 1.7388 - val_categorical_accuracy: 0.7589 - lr: 2.5000e-05 - 7s/epoch - 249ms/step
# Epoch 181/250
#
# Epoch 181: saving model to model_181.ckpt
# 27/27 - 7s - loss: 0.9549 - categorical_accuracy: 0.9657 - val_loss: 1.7439 - val_categorical_accuracy: 0.7494 - lr: 2.5000e-05 - 7s/epoch - 251ms/step
# Epoch 182/250
#
# Epoch 182: saving model to model_182.ckpt
# 27/27 - 7s - loss: 0.9501 - categorical_accuracy: 0.9663 - val_loss: 1.7401 - val_categorical_accuracy: 0.7636 - lr: 2.5000e-05 - 7s/epoch - 251ms/step
# Epoch 183/250
#
# Epoch 183: saving model to model_183.ckpt
# 27/27 - 7s - loss: 0.9345 - categorical_accuracy: 0.9734 - val_loss: 1.7356 - val_categorical_accuracy: 0.7754 - lr: 2.5000e-05 - 7s/epoch - 249ms/step
# Epoch 184/250
#
# Epoch 184: saving model to model_184.ckpt
# 27/27 - 7s - loss: 0.9461 - categorical_accuracy: 0.9610 - val_loss: 1.7585 - val_categorical_accuracy: 0.7541 - lr: 2.5000e-05 - 7s/epoch - 256ms/step
# Epoch 185/250
#
# Epoch 185: saving model to model_185.ckpt
# 27/27 - 7s - loss: 0.9522 - categorical_accuracy: 0.9580 - val_loss: 1.7573 - val_categorical_accuracy: 0.7470 - lr: 2.5000e-05 - 7s/epoch - 250ms/step
# Epoch 186/250
#
# Epoch 186: saving model to model_186.ckpt
# 27/27 - 7s - loss: 0.9410 - categorical_accuracy: 0.9634 - val_loss: 1.7684 - val_categorical_accuracy: 0.7447 - lr: 2.5000e-05 - 7s/epoch - 249ms/step
# Epoch 187/250
#
# Epoch 187: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 187: saving model to model_187.ckpt
# 27/27 - 7s - loss: 0.9377 - categorical_accuracy: 0.9586 - val_loss: 1.7360 - val_categorical_accuracy: 0.7541 - lr: 2.5000e-05 - 7s/epoch - 257ms/step
# Epoch 188/250
#
# Epoch 188: saving model to model_188.ckpt
# 27/27 - 7s - loss: 0.9310 - categorical_accuracy: 0.9669 - val_loss: 1.7180 - val_categorical_accuracy: 0.7730 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 189/250
#
# Epoch 189: saving model to model_189.ckpt
# 27/27 - 7s - loss: 0.9143 - categorical_accuracy: 0.9758 - val_loss: 1.7251 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 190/250
#
# Epoch 190: saving model to model_190.ckpt
# 27/27 - 7s - loss: 0.9310 - categorical_accuracy: 0.9628 - val_loss: 1.7375 - val_categorical_accuracy: 0.7541 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 191/250
#
# Epoch 191: saving model to model_191.ckpt
# 27/27 - 7s - loss: 0.9201 - categorical_accuracy: 0.9634 - val_loss: 1.7194 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 248ms/step
# Epoch 192/250
#
# Epoch 192: saving model to model_192.ckpt
# 27/27 - 7s - loss: 0.9154 - categorical_accuracy: 0.9734 - val_loss: 1.7229 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 193/250
#
# Epoch 193: saving model to model_193.ckpt
# 27/27 - 7s - loss: 0.9029 - categorical_accuracy: 0.9781 - val_loss: 1.7139 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 194/250
#
# Epoch 194: saving model to model_194.ckpt
# 27/27 - 7s - loss: 0.8965 - categorical_accuracy: 0.9740 - val_loss: 1.7223 - val_categorical_accuracy: 0.7636 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 195/250
#
# Epoch 195: saving model to model_195.ckpt
# 27/27 - 7s - loss: 0.9091 - categorical_accuracy: 0.9675 - val_loss: 1.7119 - val_categorical_accuracy: 0.7754 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 196/250
#
# Epoch 196: saving model to model_196.ckpt
# 27/27 - 7s - loss: 0.9209 - categorical_accuracy: 0.9639 - val_loss: 1.7492 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 197/250
#
# Epoch 197: saving model to model_197.ckpt
# 27/27 - 7s - loss: 0.9011 - categorical_accuracy: 0.9734 - val_loss: 1.7515 - val_categorical_accuracy: 0.7541 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 198/250
#
# Epoch 198: saving model to model_198.ckpt
# 27/27 - 7s - loss: 0.8943 - categorical_accuracy: 0.9746 - val_loss: 1.7089 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 199/250
#
# Epoch 199: saving model to model_199.ckpt
# 27/27 - 7s - loss: 0.9138 - categorical_accuracy: 0.9704 - val_loss: 1.7290 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 200/250
#
# Epoch 200: saving model to model_200.ckpt
# 27/27 - 7s - loss: 0.8855 - categorical_accuracy: 0.9764 - val_loss: 1.7235 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 251ms/step
# Epoch 201/250
#
# Epoch 201: saving model to model_201.ckpt
# 27/27 - 7s - loss: 0.9008 - categorical_accuracy: 0.9734 - val_loss: 1.7029 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 202/250
#
# Epoch 202: saving model to model_202.ckpt
# 27/27 - 7s - loss: 0.8926 - categorical_accuracy: 0.9805 - val_loss: 1.7223 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 203/250
#
# Epoch 203: saving model to model_203.ckpt
# 27/27 - 7s - loss: 0.8840 - categorical_accuracy: 0.9793 - val_loss: 1.7035 - val_categorical_accuracy: 0.7565 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 204/250
#
# Epoch 204: saving model to model_204.ckpt
# 27/27 - 7s - loss: 0.8875 - categorical_accuracy: 0.9781 - val_loss: 1.7018 - val_categorical_accuracy: 0.7730 - lr: 1.2500e-05 - 7s/epoch - 252ms/step
# Epoch 205/250
#
# Epoch 205: saving model to model_205.ckpt
# 27/27 - 7s - loss: 0.8844 - categorical_accuracy: 0.9710 - val_loss: 1.7020 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 206/250
#
# Epoch 206: saving model to model_206.ckpt
# 27/27 - 7s - loss: 0.8908 - categorical_accuracy: 0.9752 - val_loss: 1.7234 - val_categorical_accuracy: 0.7541 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 207/250
#
# Epoch 207: saving model to model_207.ckpt
# 27/27 - 7s - loss: 0.8805 - categorical_accuracy: 0.9775 - val_loss: 1.7401 - val_categorical_accuracy: 0.7683 - lr: 1.2500e-05 - 7s/epoch - 251ms/step
# Epoch 208/250
#
# Epoch 208: saving model to model_208.ckpt
# 27/27 - 7s - loss: 0.8840 - categorical_accuracy: 0.9722 - val_loss: 1.6980 - val_categorical_accuracy: 0.7636 - lr: 1.2500e-05 - 7s/epoch - 251ms/step
# Epoch 209/250
#
# Epoch 209: saving model to model_209.ckpt
# 27/27 - 7s - loss: 0.8735 - categorical_accuracy: 0.9799 - val_loss: 1.7190 - val_categorical_accuracy: 0.7660 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 210/250
#
# Epoch 210: saving model to model_210.ckpt
# 27/27 - 7s - loss: 0.8780 - categorical_accuracy: 0.9734 - val_loss: 1.7204 - val_categorical_accuracy: 0.7494 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 211/250
#
# Epoch 211: saving model to model_211.ckpt
# 27/27 - 7s - loss: 0.8778 - categorical_accuracy: 0.9704 - val_loss: 1.7357 - val_categorical_accuracy: 0.7447 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 212/250
#
# Epoch 212: saving model to model_212.ckpt
# 27/27 - 7s - loss: 0.8754 - categorical_accuracy: 0.9758 - val_loss: 1.7033 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 250ms/step
# Epoch 213/250
#
# Epoch 213: saving model to model_213.ckpt
# 27/27 - 7s - loss: 0.8751 - categorical_accuracy: 0.9799 - val_loss: 1.6986 - val_categorical_accuracy: 0.7683 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 214/250
#
# Epoch 214: saving model to model_214.ckpt
# 27/27 - 7s - loss: 0.8678 - categorical_accuracy: 0.9799 - val_loss: 1.7104 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 215/250
#
# Epoch 215: saving model to model_215.ckpt
# 27/27 - 7s - loss: 0.8762 - categorical_accuracy: 0.9704 - val_loss: 1.7251 - val_categorical_accuracy: 0.7612 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 216/250
#
# Epoch 216: saving model to model_216.ckpt
# 27/27 - 7s - loss: 0.8635 - categorical_accuracy: 0.9805 - val_loss: 1.7001 - val_categorical_accuracy: 0.7636 - lr: 1.2500e-05 - 7s/epoch - 259ms/step
# Epoch 217/250
#
# Epoch 217: saving model to model_217.ckpt
# 27/27 - 7s - loss: 0.8711 - categorical_accuracy: 0.9787 - val_loss: 1.7533 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 249ms/step
# Epoch 218/250
#
# Epoch 218: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 218: saving model to model_218.ckpt
# 27/27 - 7s - loss: 0.8598 - categorical_accuracy: 0.9811 - val_loss: 1.7228 - val_categorical_accuracy: 0.7589 - lr: 1.2500e-05 - 7s/epoch - 251ms/step
# Epoch 219/250
#
# Epoch 219: saving model to model_219.ckpt
# 27/27 - 7s - loss: 0.8656 - categorical_accuracy: 0.9775 - val_loss: 1.7253 - val_categorical_accuracy: 0.7636 - lr: 6.2500e-06 - 7s/epoch - 250ms/step
# Epoch 220/250
#
# Epoch 220: saving model to model_220.ckpt
# 27/27 - 7s - loss: 0.8551 - categorical_accuracy: 0.9805 - val_loss: 1.7206 - val_categorical_accuracy: 0.7660 - lr: 6.2500e-06 - 7s/epoch - 250ms/step
# Epoch 221/250
#
# Epoch 221: saving model to model_221.ckpt
# 27/27 - 7s - loss: 0.8675 - categorical_accuracy: 0.9770 - val_loss: 1.7260 - val_categorical_accuracy: 0.7541 - lr: 6.2500e-06 - 7s/epoch - 250ms/step
# Epoch 222/250
#
# Epoch 222: saving model to model_222.ckpt
# 27/27 - 7s - loss: 0.8593 - categorical_accuracy: 0.9781 - val_loss: 1.7183 - val_categorical_accuracy: 0.7589 - lr: 6.2500e-06 - 7s/epoch - 252ms/step
# Epoch 223/250
#
# Epoch 223: saving model to model_223.ckpt
# 27/27 - 7s - loss: 0.8458 - categorical_accuracy: 0.9835 - val_loss: 1.7171 - val_categorical_accuracy: 0.7636 - lr: 6.2500e-06 - 7s/epoch - 249ms/step
# Epoch 224/250
#
# Epoch 224: saving model to model_224.ckpt
# 27/27 - 7s - loss: 0.8469 - categorical_accuracy: 0.9829 - val_loss: 1.7132 - val_categorical_accuracy: 0.7589 - lr: 6.2500e-06 - 7s/epoch - 258ms/step
# Epoch 225/250
#
# Epoch 225: saving model to model_225.ckpt
# 27/27 - 7s - loss: 0.8504 - categorical_accuracy: 0.9811 - val_loss: 1.7065 - val_categorical_accuracy: 0.7636 - lr: 6.2500e-06 - 7s/epoch - 253ms/step
# Epoch 226/250
#
# Epoch 226: saving model to model_226.ckpt
# 27/27 - 7s - loss: 0.8541 - categorical_accuracy: 0.9805 - val_loss: 1.7246 - val_categorical_accuracy: 0.7589 - lr: 6.2500e-06 - 7s/epoch - 250ms/step
# Epoch 227/250
#
# Epoch 227: saving model to model_227.ckpt
# 27/27 - 7s - loss: 0.8529 - categorical_accuracy: 0.9805 - val_loss: 1.7049 - val_categorical_accuracy: 0.7636 - lr: 6.2500e-06 - 7s/epoch - 250ms/step
# Epoch 228/250
#
# Epoch 228: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 228: saving model to model_228.ckpt
# 27/27 - 7s - loss: 0.8575 - categorical_accuracy: 0.9722 - val_loss: 1.7016 - val_categorical_accuracy: 0.7589 - lr: 6.2500e-06 - 7s/epoch - 252ms/step
# Epoch 229/250
#
# Epoch 229: saving model to model_229.ckpt
# 27/27 - 7s - loss: 0.8489 - categorical_accuracy: 0.9840 - val_loss: 1.7075 - val_categorical_accuracy: 0.7589 - lr: 3.1250e-06 - 7s/epoch - 250ms/step
# Epoch 230/250
#
# Epoch 230: saving model to model_230.ckpt
# 27/27 - 7s - loss: 0.8428 - categorical_accuracy: 0.9840 - val_loss: 1.7060 - val_categorical_accuracy: 0.7589 - lr: 3.1250e-06 - 7s/epoch - 249ms/step
# Epoch 231/250
#
# Epoch 231: saving model to model_231.ckpt
# 27/27 - 7s - loss: 0.8505 - categorical_accuracy: 0.9811 - val_loss: 1.7227 - val_categorical_accuracy: 0.7565 - lr: 3.1250e-06 - 7s/epoch - 256ms/step
# Epoch 232/250
#
# Epoch 232: saving model to model_232.ckpt
# 27/27 - 7s - loss: 0.8485 - categorical_accuracy: 0.9793 - val_loss: 1.7097 - val_categorical_accuracy: 0.7589 - lr: 3.1250e-06 - 7s/epoch - 250ms/step
# Epoch 233/250
#
# Epoch 233: saving model to model_233.ckpt
# 27/27 - 7s - loss: 0.8408 - categorical_accuracy: 0.9858 - val_loss: 1.7031 - val_categorical_accuracy: 0.7541 - lr: 3.1250e-06 - 7s/epoch - 250ms/step
# Epoch 234/250
#
# Epoch 234: saving model to model_234.ckpt
# 27/27 - 7s - loss: 0.8486 - categorical_accuracy: 0.9811 - val_loss: 1.7134 - val_categorical_accuracy: 0.7565 - lr: 3.1250e-06 - 7s/epoch - 252ms/step
# Epoch 235/250
#
# Epoch 235: saving model to model_235.ckpt
# 27/27 - 7s - loss: 0.8418 - categorical_accuracy: 0.9846 - val_loss: 1.7260 - val_categorical_accuracy: 0.7541 - lr: 3.1250e-06 - 7s/epoch - 250ms/step
# Epoch 236/250
#
# Epoch 236: saving model to model_236.ckpt
# 27/27 - 7s - loss: 0.8520 - categorical_accuracy: 0.9793 - val_loss: 1.7224 - val_categorical_accuracy: 0.7565 - lr: 3.1250e-06 - 7s/epoch - 250ms/step
# Epoch 237/250
#
# Epoch 237: saving model to model_237.ckpt
# 27/27 - 7s - loss: 0.8379 - categorical_accuracy: 0.9846 - val_loss: 1.7182 - val_categorical_accuracy: 0.7589 - lr: 3.1250e-06 - 7s/epoch - 251ms/step
# Epoch 238/250
#
# Epoch 238: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 238: saving model to model_238.ckpt
# 27/27 - 7s - loss: 0.8393 - categorical_accuracy: 0.9846 - val_loss: 1.7198 - val_categorical_accuracy: 0.7636 - lr: 3.1250e-06 - 7s/epoch - 251ms/step
# Epoch 239/250
#
# Epoch 239: saving model to model_239.ckpt
# 27/27 - 7s - loss: 0.8419 - categorical_accuracy: 0.9840 - val_loss: 1.7177 - val_categorical_accuracy: 0.7612 - lr: 1.5625e-06 - 7s/epoch - 250ms/step
# Epoch 240/250
#
# Epoch 240: saving model to model_240.ckpt
# 27/27 - 7s - loss: 0.8407 - categorical_accuracy: 0.9829 - val_loss: 1.7186 - val_categorical_accuracy: 0.7589 - lr: 1.5625e-06 - 7s/epoch - 251ms/step
# Epoch 241/250
#
# Epoch 241: saving model to model_241.ckpt
# 27/27 - 7s - loss: 0.8486 - categorical_accuracy: 0.9770 - val_loss: 1.7139 - val_categorical_accuracy: 0.7589 - lr: 1.5625e-06 - 7s/epoch - 250ms/step
# Epoch 242/250
#
# Epoch 242: saving model to model_242.ckpt
# 27/27 - 7s - loss: 0.8439 - categorical_accuracy: 0.9775 - val_loss: 1.7153 - val_categorical_accuracy: 0.7589 - lr: 1.5625e-06 - 7s/epoch - 250ms/step
# Epoch 243/250
#
# Epoch 243: saving model to model_243.ckpt
# 27/27 - 7s - loss: 0.8444 - categorical_accuracy: 0.9805 - val_loss: 1.7147 - val_categorical_accuracy: 0.7612 - lr: 1.5625e-06 - 7s/epoch - 251ms/step
# Epoch 244/250
#
# Epoch 244: saving model to model_244.ckpt
# 27/27 - 7s - loss: 0.8445 - categorical_accuracy: 0.9811 - val_loss: 1.7184 - val_categorical_accuracy: 0.7589 - lr: 1.5625e-06 - 7s/epoch - 250ms/step
# Epoch 245/250
#
# Epoch 245: saving model to model_245.ckpt
# 27/27 - 7s - loss: 0.8335 - categorical_accuracy: 0.9864 - val_loss: 1.7192 - val_categorical_accuracy: 0.7612 - lr: 1.5625e-06 - 7s/epoch - 250ms/step
# Epoch 246/250
#
# Epoch 246: saving model to model_246.ckpt
# 27/27 - 7s - loss: 0.8417 - categorical_accuracy: 0.9775 - val_loss: 1.7163 - val_categorical_accuracy: 0.7636 - lr: 1.5625e-06 - 7s/epoch - 251ms/step
# Epoch 247/250
#
# Epoch 247: saving model to model_247.ckpt
# 27/27 - 7s - loss: 0.8502 - categorical_accuracy: 0.9758 - val_loss: 1.7193 - val_categorical_accuracy: 0.7660 - lr: 1.5625e-06 - 7s/epoch - 250ms/step
# Epoch 248/250
#
# Epoch 248: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#
# Epoch 248: saving model to model_248.ckpt
# 27/27 - 7s - loss: 0.8497 - categorical_accuracy: 0.9787 - val_loss: 1.7158 - val_categorical_accuracy: 0.7589 - lr: 1.5625e-06 - 7s/epoch - 251ms/step
# Epoch 249/250
#
# Epoch 249: saving model to model_249.ckpt
# 27/27 - 7s - loss: 0.8491 - categorical_accuracy: 0.9770 - val_loss: 1.7153 - val_categorical_accuracy: 0.7589 - lr: 7.8125e-07 - 7s/epoch - 250ms/step
# Epoch 250/250
#
# Epoch 250: saving model to model_250.ckpt
# 27/27 - 7s - loss: 0.8257 - categorical_accuracy: 0.9905 - val_loss: 1.7127 - val_categorical_accuracy: 0.7612 - lr: 7.8125e-07 - 7s/epoch - 249ms/step

# %%
import numpy as np
max_idx = np.argmax(acc_list) + 1
print(max_idx)
best_filename = 'model_{:03d}.ckpt'.format(max_idx)
model.load_weights(best_filename)
print('\nTest accuracy')
loss, acc = model.evaluate(X_test.transpose((0, 2, 1)), y_test_1h)
print("Test accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 206
#
# Test accuracy
# 14/14 [==============================] - 1s 40ms/step - loss: 1.8673 - categorical_accuracy: 0.7472
# Test accuracy: 74.72%
